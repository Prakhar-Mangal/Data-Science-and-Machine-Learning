# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakhar-Mangal/Data-Science-and-Machine-Learning/blob/master/%234_gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 10000
  n = len(x)
  learning_rate = 0.01
  plt.scatter(x,y,color='red',marker='+')
  for i in range(iterations):
    y_predicted = m_curr*x + b_curr
    plt.plot(x,y_predicted,color='green')
    cost = 1/n*sum([val**2 for val in (y-y_predicted)])
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate*md
    b_curr = b_curr - learning_rate*bd 

    print(f"m {m_curr}, b {b_curr}, cost {cost} iteration {i} ")



x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.0000000276546004, b 2.999999900158118, cost 1.826754969563614e-15 iteration 5001
# m 2.0000000275611014, b 2.9999999004956797, cost 1.81442346865097e-15 iteration 5002
# m 2.000000027467918, b 2.9999999008321, cost 1.802175231104541e-15 iteration 5003
# m 2.0000000273750502, b 2.999999901167383, cost 1.7900096116236763e-15 iteration 5004
# m 2.0000000272824963, b 2.999999901501532, cost 1.7779261911764547e-15 iteration 5005
# m 2.0000000271902554, b 2.9999999018345513, cost 1.7659243149753253e-15 iteration 5006
# m 2.0000000270983262, b 2.999999902166445, cost 1.7540034779000308e-15 iteration 5007
# m 2.0000000270067075, b 2.9999999024972164, cost 1.7421631063296812e-15 iteration 5008
# m 2.000000026915399, b 2.9999999028268696, cost 1.7304026364503835e-15 iteration 5009
# m 2.0000000268243987, b 2.999999903155408, cost 1.7187215496941953e-15 iteration 5010
# ...

# %%
a = np.array([1,2,3,4])
a = a*2+3
b = np.array([3,7,10,12])
a-b
# Out:
# array([ 2,  0, -1, -1])

# %% [markdown]
# # Exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/codebasics/py/master/ML/3_gradient_descent/Exercise/test_scores.csv'
df = pd.read_csv(url)
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
import math
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000000
  n = len(x)
  cost_previous = 0
  learning_rate = 0.0002
  plt.scatter(x,y,color='red',marker='+')
  for i in range(iterations):
    y_predicted = m_curr*x + b_curr
    plt.plot(x,y_predicted,color='green')
    cost = 1/n*sum([val**2 for val in (y-y_predicted)])

    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate*md
    b_curr = b_curr - learning_rate*bd
    if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break
    cost_previous = cost

    print(f"m {m_curr}, b {b_curr}, cost {cost} iteration {i} ")

x = np.array(df['math'])
y = np.array(df['cs'])

gradient_descent(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.0177384013109885, b 1.9150659927837017, cost 31.604511334879064 iteration 410534
# m 1.0177384012613204, b 1.9150659963035586, cost 31.60451133487899 iteration 410535
# m 1.017738401211653, b 1.9150659998233346, cost 31.60451133487895 iteration 410536
# m 1.0177384011619872, b 1.9150660033430298, cost 31.604511334878886 iteration 410537
# m 1.0177384011123225, b 1.9150660068626444, cost 31.60451133487882 iteration 410538
# m 1.0177384010626587, b 1.9150660103821782, cost 31.604511334878765 iteration 410539
# m 1.0177384010129964, b 1.9150660139016311, cost 31.604511334878694 iteration 410540
# m 1.0177384009633348, b 1.9150660174210032, cost 31.60451133487865 iteration 410541
# m 1.017738400913675, b 1.9150660209402945, cost 31.60451133487858 iteration 410542
# m 1.0177384008640151, b 1.915066024459505, cost 31.604511334878516 iteration 410543
# ...

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit(df[['math']],df['cs'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.intercept_ # similar to that comes from gradient_descent
# Out:
# 1.9152193111569034

# %%
reg.coef_ # gradient_descent
# Out:
# array([1.01773624])
